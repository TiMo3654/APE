# %%
print('Poop')
# Out:
# Poop

# %%
import pandas as pd

# %%
df = pd.read_csv('database.csv')

df
# Out:
#                                                 title conference  year  \
# 0   Trade-Off Between Accuracy and Computational T...        DMC  2021
# 1   Automated design of integrated inductive compo...        DMC  2021
# 2   Efficient Design and Optimization of Large DC ...        DMC  2021
# 3   Full Analytical Topology-Device Selection and ...        DMC  2021
# 4   Optimal Design Automation Tool for LLC Convert...        DMC  2021
# 5   Machine Learning Estimators for Power Electron...        DMC  2021
# 6       Placement and Routing for Power Module Layout        DMC  2021
# 7   PowerSynth Integrated CAD flow for High Densit...        DMC  2021
# 8   Design Methodology for High Performance Electr...        DMC  2021
# 9   Online Health Monitoring in Power Modules for ...        DMC  2021
# 10  Design Automation Combining Analytical Models ...        DMC  2021
# 11  An Advanced Persistent Threat (APT)-Style Cybe...        DMC  2021
# ...

# %%
df["label5"].value_counts(normalize=True).plot.pie(autopct='%.1f %%', ylabel='', legend=True)
# Out:
# <Axes: >
