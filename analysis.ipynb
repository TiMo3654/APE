# %%
print('Poop')
# Out:
# Poop

# %%
import pandas as pd

# %%
df = pd.read_csv('dmc_analysis_1.csv')

df
# Out:
#     Year        ID                                              Title  \
# 0   2022   9906474  Machine Learning-based Component Figures of Me...
# 1   2022   9906538  Device-Centric Firmware Malware Detection for ...
# 2   2022   9906542  Virtual PCB Layout Prototyping: Importance of ...
# 3   2022   9906473  Broad-Scale Converter Optimization Utilizing D...
# 4   2022   9906470  Genetic Algorithm-Based Optimized Modulation F...
# ..   ...       ...                                                ...
# 64  2023  10412423  Machine Learning Based Non-Intrusive Inspectio...
# 65  2021   9529939  A Multi-Objective Genetic Algorithm Methodolog...
# 66  2021   9529941  Design of a Bidirectional DC/DC Converter for ...
# 67  2021   9529951  Efficient Design and Optimization of Large DC ...
# 68  2021   9529952  Full Analytical Topology-Device Selection and ...
#
#     Citations              Track      Domain    Level               Target  \
# ...

# %%
df["Task"].value_counts(normalize=True).plot.pie(autopct='%.1f %%', ylabel='', legend=False)
# Out:
# <Axes: >

# %%
df["Track"].value_counts(normalize=False).plot(kind='barh', title ="Track", fontsize=12)
# Out:
# <Axes: title={'center': 'Track'}, ylabel='Track'>

# %%
df.sort_values('Citations', ascending=False).head(10)
# Out:
#     Year        ID                                              Title  \
# 35  2021   9529949  Blockchain-Based Man-in-the-Middle (MITM) Atta...
# 36  2021   9529953  An Advanced Persistent Threat (APT)-Style Cybe...
# 37  2021   9529935  Cyber Protection of Grid-Connected Devices Thr...
# 0   2022   9906474  Machine Learning-based Component Figures of Me...
# 1   2022   9906538  Device-Centric Firmware Malware Detection for ...
# 38  2021   9529937  Machine Learning Estimators for Power Electron...
# 17  2023  10412561  Analyzing the Effects of Interference and Pack...
# 39  2021   9529940      Placement and Routing for Power Module Layout
# 42  2021   9529945  PowerSynth Integrated CAD flow for High Densit...
# 44  2021   9529938  A Component Manipulation Algorithm to Enable D...
#
#     Citations              Track      Domain    Level        Target  \
# 35         12      Cybersecurity         NaN   System          Grid
# ...

# %%
df[df.Availability == 'Open-Source'].sort_values('Citations', ascending=False)
# Out:
#     Year       ID                                              Title  \
# 47  2021  9529930  Design Automation Combining Analytical Models ...
#
#     Citations              Track      Domain    Level    Target Application  \
# 47          2  Design Automation  Electrical  Circuit  Discrete   Inverter
#
#    Algorithm Availability             Task         Paradigm
# 47       NaN  Open-Source  Circuit Concept  Knowledge-based

# %%
df[df.Task == 'Model Building'].sort_values('Citations', ascending=False)
# Out:
#     Year        ID                                              Title  \
# 0   2022   9906474  Machine Learning-based Component Figures of Me...
# 38  2021   9529937  Machine Learning Estimators for Power Electron...
# 43  2021   9529932  Trade-Off Between Accuracy and Computational T...
# 2   2022   9906542  Virtual PCB Layout Prototyping: Importance of ...
# 18  2023  10412460  State of Charge Estimation Using Data-Driven M...
# 50  2021   9529931  Characterization and modeling of 650V GaN diod...
# 51  2021   9529943  Fast and Accurate Electric Field Model for Opt...
# 8   2022   9906539  Implementation of Multi-Expansion Point Model ...
# 53  2021   9529936  Automated design of integrated inductive compo...
# 52  2021   9529934  Estimation of Switching Losses using Simplifie...
# 14  2022   9906475  Methodology for Designing Embedded Real-Time E...
# 12  2022   9906469  Towards Real Time Thermal Simulations for Desi...
# ...
